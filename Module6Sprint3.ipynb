# %%
import mysql.connector
changes=mysql.connector.connect(host='127.0.0.1',user='root',passwd='Mathapelo63')

cursor=changes.cursor()


cursor.execute('SHOW DATABASES')
for x in cursor:
    print(x)
# Out:
# ('data1',)
# ('information_schema',)
# ('irma',)
# ('mydatabase',)
# ('mysql',)
# ('newdata',)
# ('performance_schema',)
# ('practicedatabase',)
# ('sakila',)
# ('sys',)
# ('test',)
# ('world',)

# %%
info=mysql.connector.connect(host='127.0.0.1',user='root',passwd='Mathapelo63',database='data1')
mycursor=info.cursor()
mycursor.execute('SHOW TABLES')
for x in mycursor:
    print(x)
# Out:
# ('data',)
# ('datasprint3',)

# %%
mycursor.execute('SHOW TABLES')
for x in mycursor:
    print(x)
# Out:
# ('data',)
# ('datasprint3',)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import mysql
import pymysql
import sqlalchemy
engine=sqlalchemy.create_engine("mysql+pymysql://root:Mathapelo63@localhost:3306/data1")
df=pd.read_sql_table("data",engine)

df[df['Profit']<0]
# Out:
#                   Name       Type   Price  Stocked  Sales   Revenue  Cost  \
# 0                 Lays      Chips   18.99     1468    580  11014.20    16
# 7              Ricoffy      Coffe   47.99      949    568  27258.32    44
# 9      Dutoitskloof RR       Wine   44.99     1203    649  29198.51    41
# 14            Potatoes  Vegetable   16.99     1284    647  10992.53    12
# 19              Tennis    Biscuit   17.99     1166    578  10398.22    15
# 21  Chicken Braai pack       Meat   45.49     1485    991  45080.59    41
# 22               halls      Juice   30.99     1068    819  25380.81    28
# 23              Albany      Bread   14.99     1254    666   9983.34    11
# 25             Tropica      Juice   22.99     1361    623  14322.77    19
# 26               Krush      Juice   26.99     1341    773  20863.27    24
# 27         Blue ribbon      Bread   12.99     1400    578   7508.22     9
# 30          Spare Ribs       Meat  112.99     1486    563  63613.37   109
# ...

# %%
word=newlist[1]

for i in range(50):
    v_input=input('Add a reference number :')
    new=["UPDATE data1.data SET ref="+v_input+" WHERE Name='Lays'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='P.S'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Steak fillets'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='MnM'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Apple'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Boerwwors'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Oros'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Ricoffy'",
    "UPDATE data1.data SET ref="+v_input+" WHERE Name='Carrots'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Dutoitskloof RR'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Mince'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Rhodes fruit juice'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='excella'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Simba'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Potatoes'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Nescafe classic'",
    "UPDATE data1.data SET ref="+v_input+" WHERE Name='Lamb stew'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='tex'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Nik naks'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Tennis'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Sunflower'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Chicken Braai pack'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='halls'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Albany'",
    "UPDATE data1.data SET ref="+v_input+" WHERE Name='Maynards'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Tropica'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Krush'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Blue ribbon'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Brocolli'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Water mellon'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Spare Ribs'", 
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Joko'",
    "UPDATE data1.data SET ref="+v_input+" WHERE Name='Tall horse dry red'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Grapes'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Avocado'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Beef broisket'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Baby hake'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='bananas'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Eet sum mor'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Nederburg'",
    "UPDATE data1.data SET ref="+v_input+" WHERE Name='Jacobs'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Cheese curls'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Onions'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='fresh pack'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Bacon'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Green beans'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='SuperC'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Pringles'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Lemon creams'",
     "UPDATE data1.data SET ref="+v_input+" WHERE Name='Paw paw'",]

    
    for x in range(len(new)):
        mycursor.execute(new[i])
info.commit()
# Out:
# Add a reference number :54464489
# Add a reference number :844894
# Add a reference number :5464844
# Add a reference number :444894849
# Add a reference number :498494
# Add a reference number :4444
# Add a reference number :8448
# Add a reference number :4984
# Add a reference number :89494
# Add a reference number :84894
# Add a reference number :848948
# Add a reference number :4894
# Add a reference number :4949
# Add a reference number :894984
# Add a reference number :844
# Add a reference number :9494
# Add a reference number :494
# Add a reference number :4944
# Add a reference number :494
# Add a reference number :98489484
# Add a reference number :8944
# Add a reference number :9844
# Add a reference number :494
# Add a reference number :49494
# Add a reference number :984984
# Add a reference number :944
# Add a reference number :949498
# Add a reference number :494
# Add a reference number :9849848
# Add a reference number :98498484
# Add a reference number :94
# ...

# %%
holder='INSERT INTO data (Name,Type,Stocked) VALUES (%s,%s,%s)'
no_=('Always','Pads','150')
mycursor.execute(holder,no_)
info.commit()
print(mycursor.rowcount,'change(s) in record')
# Out:
# 1 change(s) in record

# %%
holder1='INSERT INTO data (Sales,Revenue,Cost) VALUES(%s,%s,%s)' 
no_1=input("Put it the data: ")
mycursor.execute(holder,no_)
info.commit()
print(mycursor.rowcount,'change(s) in record')

# %%
holder2='INSERT INTO data (VAT Returned,Profit,ref) VALUES(%s,%s,%s)'
no_2=input("Put it the data: ")
mycursor.execute(holder,no_2)
info.commit()
print(mycursor.rowcount,'change(s) in record')
# Out:
# Put it the data: ('15','154','231545465464')
# 1 change(s) in record

# %%
import mysql.connector
changs=mysql.connector.connect(host='127.0.0.1',user='root',passwd='Mathapelo63',database='data1')

cursor=changs.cursor()

cursor.execute("CREATE TABLE data1.shop (rank INT(15))")
cursor.execute("SHOW TABLES")
for x in cursor:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-4-94f4e4911d0c> in <module>
#       4 cursor=changs.cursor()
#       5
# ----> 6 cursor.execute("CREATE TABLE data1.shop (rank INT(15))")
#       7 cursor.execute("SHOW TABLES")
#       8 for x in cursor:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
# ...

# %%
holder2='INSERT INTO data (VAT Returned,Profit,ref) VALUES(%s,%s,%s)'
no_4=input("Put it the data: ")
cursor.execute(holder,no_4)
info.commit()
print(cursor.rowcount,'change(s) in record')

# %%
for i in range(3):
    colName=input("Enter colName")
    query = "ALTER TABLE sprint3 ADD %s INT(15)" % (colName)
    cursor.execute(query)

# %%
sql ="CREATE TABLE shoes (FIRST_NAME CHAR(20) NOT NULL,LAST_NAME CHAR(20),AGE INT,SEX CHAR(1),INCOME FLOAT)"
cursor.execute(sql)

# %%
cursor.execute("SHOW TABLES")
for x in cursor:
    print(x)
# Out:
# ('data',)
# ('datasprint3',)
# ('employee',)
# ('shoes',)
